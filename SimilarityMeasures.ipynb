# %% [markdown]
# # Textvergleich mit unterschiedlichen Methoden für Korpora
#
# Das Notebook bietet einen Satz-weisen Vergleich von Texten aus einem Korpus mit Hilfe von drei verschiedenen Methoden:
# - TF/IDF
# - Fasttext Embeddings
# - MinHash
#
# Für jede Methode gibt es eine Funktion, die
# 1. ein Dataframe erstellt, der die Abstände zwischen den Sätzen enthält
# 2. alle jene Satzpaare anzeigt, deren Ähnlichkeit einen gewissen Wert überschreitet.
#
# Diese Funktionen können auf ein nltk-Korpus angewandt werden, um den Zieltext mit den anderen zu vergleichen.
#
# Das Notebook stammt aus dem Kurs "Intertextualität und Text Re-Use" und wurde wo nötig abgeändert: Tokenizen brauche ich nicht, da ich die schon lemmatizeten Texte verwende. Stattdessen müssen die Sätze abgetrennt werden (allerdings verwendet Altgriechisch andere Satzzeichen). Für den Fasttext Vergleich habe ich mein eigenes Model trainiert (siehe TrainWordembedding.py hat in Jupyter nicht funktioniert). Sentence Embeddings habe ich in Ermangelung eines Models für Altgriechisch nicht gemacht.

# %% [markdown]
# ### Import von Packages

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
from datasketch import MinHash
import unicodedata

# %% [markdown]
# ### Processing Funktionen

# %%
#Unterteil griechischen Text in Sätze. Da Altgriechisch andere Satzzeichen verwendet habe ich meine eigene Funktion geschrieben.
def make_sentences_str(text):
    sentences = []
    sentence = ""
    tokens = text.split()
    for word in tokens:
        word = word.replace('᾽', '' ).replace('῞', '') 
        if word in [',', '\n', "'", "᾽", '῞',""]:
            continue
        elif word in [';', ':', '.']:
            if sentence:
                sentences.append(sentence[:-1])
                sentence = ""
        else:
            sentence += word+" "
    return sentences

# %%
def make_sentences_list(text):
    sentences = []
    sentence = []
    text = text.replace('.', ' . ')
    tokens = text.split()
    for word in tokens:
        word = word.replace('᾽', '' ).replace('῞', '') 
        if word in [',', '\n', "'", "᾽", ""]:
            continue
        elif word in [';', ':', '.']:
            if sentence:
                sentences.append(sentence)
                sentence = []
        else:
            sentence.append(word)
    return sentences

# %% [markdown]
# ### Textvergleich mit TF/IDF
#
# Beide Texte werden zusammengefasst und auf dem Gesamtkorpus die TF/IDF-Vektoren berechnet.

# %%
def calculate_tfidf_similarity(text1, text2):
    # Split the texts into sentences
    sentences1 = make_sentences_str(text1)
    sentences2 = make_sentences_str(text2)

    # Combine all sentences for vectorization
    all_sentences = sentences1 + sentences2

    # Compute TF-IDF vectors
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(all_sentences)

    # Split TF-IDF matrix into two parts: one for each text
    tfidf1 = tfidf_matrix[:len(sentences1)]
    tfidf2 = tfidf_matrix[len(sentences1):]

    # Compute pairwise cosine similarity
    similarity_matrix = cosine_similarity(tfidf1, tfidf2)

    # Create a pandas DataFrame
    df = pd.DataFrame(
        similarity_matrix,
        index=range(len(sentences1)),
        columns=range(len(sentences2))
    )

    return df, sentences1, sentences2

# %% [markdown]
# ### Textvergleich mit Fasttext
#
# Das Fasttext-Modell wird aus den beiden Texten generiert.
#
# Eventuell wäre es zuverlässiger, ein auf einem größeren Korpus vortrainiertes Modell zu laden.

# %%
from gensim.models import KeyedVectors

# %%
def calculate_fasttext_similarity(text1, text2):
    # Split the texts into sentences
    sentences1 = make_sentences_list(text1)
    sentences2 = make_sentences_list(text2)

    # Train a FastText model on combined sentences
    keyed_vectors = KeyedVectors.load("cbow_keyedvectors.kv")

    # Compute sentence embeddings by averaging word vectors
    embeddings1 = [sum(keyed_vectors[unicodedata.normalize("NFC", word) ] for word in sentence)/ len(sentence) for sentence in sentences1]
    embeddings2 = [sum(keyed_vectors[unicodedata.normalize("NFC", word) ] for word in sentence)/ len(sentence) for sentence in sentences2]

    # Compute pairwise cosine similarity
    similarity_matrix = cosine_similarity(embeddings1, embeddings2)

    # Create a pandas DataFrame
    df = pd.DataFrame(
        similarity_matrix,
        index=range(len(sentences1)),
        columns=range(len(sentences2))
    )

    return df, sentences1, sentences2

# %% [markdown]
# ### Textvergleich mit minHash

# %%
def calculate_minhash_similarity(text1, text2):
    # Split the texts into sentences
    sentences1 = make_sentences_list(text1)
    sentences2 = make_sentences_list(text2)

    # Create MinHash objects for each sentence
    def get_minhash(sentence):
        minhash = MinHash()
        for word in sentence:
            minhash.update(word.encode('utf8'))
        return minhash

    minhashes1 = [get_minhash(sentence) for sentence in sentences1]
    minhashes2 = [get_minhash(sentence) for sentence in sentences2]

    # Compute pairwise MinHash similarity
    similarity_matrix = [
        [m1.jaccard(m2) for m2 in minhashes2]
        for m1 in minhashes1
    ]

    # Create a pandas DataFrame
    df = pd.DataFrame(
        similarity_matrix,
        index=range(len(sentences1)),
        columns=range(len(sentences2))
    )

    return df, sentences1, sentences2

# %% [markdown]
# ### Funktion, die alle Sätze mit Ähnlichkeitswerten über einem gewissen Threshold ermittelt.

# %%
def get_sentence_pairs_above_threshold(df, sentences1, sentences2, threshold):
    """Get all sentence pairs with similarity above the given threshold."""
    pairs = []
    for i, row in df.iterrows():
        for j, similarity in row.items():
            if similarity > threshold:
                pairs.append({
                    "sentence1": sentences1[i],
                    "sentence2": sentences2[j],
                    "similarity": similarity
                })
    return pairs

# %% [markdown]
# ## Ausführung

# %% [markdown]
# ### NLTK-Korpus anlegen

# %%
from nltk.corpus import CategorizedPlaintextCorpusReader

# %%
path = 'Lemma Text Files'

# %%
mycorpus = CategorizedPlaintextCorpusReader(path, r'.*\.txt', cat_pattern = r'(.*?)_.*')
print(len(mycorpus.fileids()), "Files importiert")
# Out:
# 37 Files importiert

# %% [markdown]
# ## Bakchen zu Platons Werken

# %% [markdown]
# Vergleichstext auswählen:

# %%
text1name='Bakchen.with_lemma.txt'

text1 = ' '.join(mycorpus.words(fileids=text1name))

# %% [markdown]
# Über Korpus iterieren:

# %%
print("Vergleich von Text ",text1name, "mit ")

for f in mycorpus.fileids():
    if f !=text1name:
        print(f)
        text2 = ' '.join(mycorpus.words(fileids=f))
        minhash_df, sentences1, sentences2 = calculate_minhash_similarity(text1, text2)
        print("Sentence pairs with similarity above 0.3 (MinHash):")
        pairs = get_sentence_pairs_above_threshold(minhash_df, sentences1, sentences2, 0.4)
        for pair in pairs:
            print(f"  - Sentence 1: {pair['sentence1']}")
            print(f"    Sentence 2: {pair['sentence2']}")
            print(f"    Similarity: {pair['similarity']:.4f}")
# Out:
# Vergleich von Text  Bakchen.with_lemma.txt mit
# Alc.+1.with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['ἀλλ', 'ἔχω', 'χείρ']
#     Sentence 2: ['ἀλλ', 'πάνυ', 'ἔχω']
#     Similarity: 0.5078
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['φημί', 'λέγω']
#     Similarity: 0.7266
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['ὠγαθὲ', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['ναυτικός', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω', 'εὐβουλία']
#     Similarity: 0.4297
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['ὀρθός', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['ὀρθός', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['ἔχω', 'δέ', 'ὄνησις', 'θύω']
#     Sentence 2: ['δέ', 'ἔχω']
#     Similarity: 0.4453
#   - Sentence 1: ['δοκέω', 'ἀμαθεύς', 'σοφός', 'λέγω', 'εὖ', 'φρονέω']
#     Sentence 2: ['εὖ', 'δοκέω', 'λέγω', 'Σώκρατες']
#     Similarity: 0.4531
#   - Sentence 1: ['νύκτωρ', 'πολύς']
#     Sentence 2: ['πολύς']
#     Similarity: 0.5156
#   - Sentence 1: ['νύκτωρ', 'πολύς']
#     Sentence 2: ['πολύς']
#     Similarity: 0.5156
#   - Sentence 1: ['νύκτωρ', 'πολύς']
#     Sentence 2: ['πολύς']
#     Similarity: 0.5156
#   - Sentence 1: ['δεῖ', 'κυριός']
#     Sentence 2: ['δεῖ']
#     Similarity: 0.5156
#   - Sentence 1: ['δεῖ', 'κυριός']
#     Sentence 2: ['δεῖ']
#     Similarity: 0.5156
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.4844
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'γίγνομαι']
#     Similarity: 0.5000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'ἔχω']
#     Similarity: 0.4375
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['διδάσκαλος', 'πῶς']
#     Similarity: 0.5156
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'ἐρωτάω']
#     Similarity: 0.5078
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.4844
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.4844
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.4844
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.4844
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.4844
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'ἔχω']
#     Similarity: 0.4766
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'ἀποκρινόμενος']
#     Similarity: 0.4922
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['καλός', 'δέ']
#     Similarity: 0.5234
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'γυμναστική']
#     Similarity: 0.5078
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'πράττω']
#     Similarity: 0.5078
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ', 'ἀναβοάω']
#     Sentence 2: ['δέ']
#     Similarity: 0.5625
#   - Sentence 1: ['δέ', 'ἀναβοάω']
#     Sentence 2: ['δέ']
#     Similarity: 0.5625
#   - Sentence 1: ['ἀλλ', 'ἐμφανής']
#     Sentence 2: ['ἀλλ']
#     Similarity: 0.4766
#   - Sentence 1: ['γυνή', 'ἀνήρ', 'τελέω']
#     Sentence 2: ['ὁμόνοια', 'γυνή', 'ἀνήρ']
#     Similarity: 0.4688
#   - Sentence 1: ['γυνή', 'ἀνήρ', 'τελέω']
#     Sentence 2: ['οὐδέ', 'ἀνήρ', 'γυνή']
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['ἀλλ', 'ἀνύω']
#     Sentence 2: ['ἀλλ']
#     Similarity: 0.5078
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω']
#     Similarity: 1.0000
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω']
#     Similarity: 1.0000
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω', 'κοινῇ']
#     Similarity: 0.5312
#   - Sentence 1: ['δέ', 'καλός', 'ὅδε', 'λυπηρός', 'ἔχω']
#     Sentence 2: ['δέ', 'ἔχω']
#     Similarity: 0.4141
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['γιγνώσκω', 'ταῦτ']
#     Sentence 2: ['ταῦτ']
#     Similarity: 0.5312
# Alc.+2.with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δοκέω']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δοκέω']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'Σώκρατες']
#     Similarity: 0.4375
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ', 'ἀναβοάω']
#     Sentence 2: ['δέ']
#     Similarity: 0.5625
#   - Sentence 1: ['ὀρθός']
#     Sentence 2: ['ὀρθός', 'δοκέω']
#     Similarity: 0.5156
#   - Sentence 1: ['ὀρθός']
#     Sentence 2: ['ὀρθός', 'δοκέω']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ', 'ἡγέομαι']
#     Sentence 2: ['δέ']
#     Similarity: 0.5391
#   - Sentence 1: ['μυρίος', 'δέ', 'μυρίος', 'ἐλπίς']
#     Sentence 2: ['δέ']
#     Similarity: 0.4062
#   - Sentence 1: ['φαίνω', 'δῆτ']
#     Sentence 2: ['φαίνω']
#     Similarity: 0.5312
#   - Sentence 1: ['φαίνω', 'δῆτ']
#     Sentence 2: ['φαίνω']
#     Similarity: 0.5312
#   - Sentence 1: ['φαίνω', 'δῆτ']
#     Sentence 2: ['φαίνω']
#     Similarity: 0.5312
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'δοκέω', 'ἀσφαλής', 'λέγω', 'ποιητής']
#     Similarity: 0.4141
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω', 'τοίνυν']
#     Similarity: 0.5078
# Apol..with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['κινδυνεύω', 'σοφός']
#     Similarity: 0.5391
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['ποτε', 'λέγω', 'θεός', 'ποτε', 'αἰνίττομαι']
#     Similarity: 0.4141
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['φημί', 'λέγω', 'λέγω']
#     Similarity: 0.7266
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πάνυ', 'δέ']
#     Similarity: 0.5234
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['κινδυνεύω', 'σοφός']
#     Similarity: 0.5391
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['κινδυνεύω', 'σοφός']
#     Similarity: 0.5391
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγ
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['οἶδα', 'ἔπος']
#     Sentence 2: ['οἶδα']
#     Similarity: 0.4688
#   - Sentence 1: ['οἶδα', 'ἔπος']
#     Sentence 2: ['οἶδα']
#     Similarity: 0.4688
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['οἶδα', 'τέκνον']
#     Sentence 2: ['οἶδα']
#     Similarity: 0.4453
#   - Sentence 1: ['οἶδα', 'τέκνον']
#     Sentence 2: ['οἶδα']
#     Similarity: 0.4453
# Criti..with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
# Crito.with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['ἀλλ', 'ἔχω', 'χείρ']
#     Sentence 2: ['ἀλλ', 'Σώκρατες', 'ἔχω', 'λέγω']
#     Similarity: 0.4219
#   - Sentence 1: ['ἀλλ', 'Πενθεύς', 'πείθω']
#     Sentence 2: ['ἀλλ', 'πείθω', 'ποιέω']
#     Similarity: 0.5391
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω', 'Κρίτων']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['νύκτωρ', 'πολύς']
#     Sentence 2: ['πολύς']
#     Similarity: 0.5156
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.4844
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['γ', 'πῶς']
#     Similarity: 0.4766
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['μένω', 'φευξούμεθα']
#     Sentence 2: ['μένω']
#     Similarity: 0.5469
#   - Sentence 1: ['μένω', 'φευξούμεθα']
#     Sentence 2: ['μένω']
#     Similarity: 0.5469
#   - Sentence 1: ['καλός', 'ἐξεῖπον']
#     Sentence 2: ['καλός']
#     Similarity: 0.5312
#   - Sentence 1: ['φαίνω', 'δῆτ']
#     Sentence 2: ['φαίνω']
#     Similarity: 0.5312
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['θεός', 'Κρίτων', 'δοκέω', 'καλός', 'λέγω']
#     Similarity: 0.4609
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'λέγω']
#     Similarity: 1.0000
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός']
#     Similarity: 0.4453
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'λέγω']
#     Similarity: 1.0000
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω', 'νόμος']
#     Similarity: 0.4062
#   - Sentence 1: ['φέρω', 'ἥκω', 'ἁβρότητ', 'λέγω']
#     Sentence 2: ['φέρω', 'πῶς', 'αὖ', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
# Epin..with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['ἀλλ', 'ὅμως', 'ἀποκάμω', 'λέγω', 'φημί']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['δύναμις', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['καλός', 'ἐξεῖπον']
#     Sentence 2: ['καλός']
#     Similarity: 0.5312
#   - Sentence 1: ['ὀρθός']
#     Sentence 2: ['ὀρθός']
#     Similarity: 1.0000
#   - Sentence 1: ['μοχλός', 'φέρω']
#     Sentence 2: ['φέρω']
#     Similarity: 0.5469
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός']
#     Similarity: 0.4453
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'ξένος', 'λέγω']
#     Similarity: 0.5938
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['δύναμις', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω']
#     Similarity: 1.0000
#   - Sentence 1: ['γιγνώσκω', 'ταῦτ']
#     Sentence 2: ['ταῦτ']
#     Similarity: 0.5312
# Epistels.with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['δρέω', 'λέγω']
#     Similarity: 0.4219
#   - Sentence 1: ['ῥᾴδιος', 'δέ', 'εἶπον']
#     Sentence 2: ['δέ', 'εἶπον']
#     Similarity: 0.6406
#   - Sentence 1: ['νύκτωρ', 'πολύς']
#     Sentence 2: ['πολύς']
#     Similarity: 0.5156
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς', 'οὔ']
#     Similarity: 0.5000
#   - Sentence 1: ['ὅδε', 'νήρ']
#     Sentence 2: ['ὅδε']
#     Similarity: 0.4844
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'εἶπον']
#     Similarity: 0.5469
#   - Sentence 1: ['δέ']
#     Sentence 2: ['ὄνομα', 'δέ', 'Λεωχάρης']
#     Similarity: 0.4062
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'χαίρω']
#     Similarity: 0.5547
#   - Sentence 1: ['ὅδε']
#     Sentence 2: ['ὅδε']
#     Similarity: 1.0000
#   - Sentence 1: ['ὅδε', 'προστίθημι']
#     Sentence 2: ['ὅδε']
#     Similarity: 0.5000
#   - Sentence 1: ['τελευτάω', 'ὄλβος', 'βροτός', 'δέ', 'ἀποβαίνω']
#     Sentence 2: ['δέ', 'εὐαγής', 'ἀποβαίνω']
#     Similarity: 0.4141
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['ὅδε', 'ἔρχομαι']
#     Sentence 2: ['ὅδε']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'εἶπον']
#     Similarity: 0.5469
#   - Sentence 1: ['δέ']
#     Sentence 2: ['ὄνομα', 'δέ', 'Λεωχάρης']
#     Similarity: 0.4062
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'χαίρω']
#     Similarity: 0.5547
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['οἶδα', 'ἔπος']
#     Sentence 2: ['οἶδα']
#     Similarity: 0.4688
#   - Sentence 1: ['οἶδα', 'τέκνον']
#     Sentence 2: ['οἶδα']
#     Similarity: 0.4453
# Euthyd..with_lemma.txt
# ...
#     Similarity: 0.5625
#   - Sentence 1: ['φεύξω', 'πᾶς']
#     Sentence 2: ['πᾶς']
#     Similarity: 0.4844
#   - Sentence 1: ['δράω']
#     Sentence 2: ['δράω', 'ἐπιλανθάνομαι']
#     Similarity: 0.4688
#   - Sentence 1: ['καλός', 'ἐξεῖπον']
#     Sentence 2: ['καλός']
#     Similarity: 0.5312
#   - Sentence 1: ['καλός', 'ἐξεῖπον']
#     Sentence 2: ['καλός']
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'λέγω', 'Θεόδωρος']
#     Similarity: 0.6719
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω', 'ἀληθής']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'λέγω']
#     Similarity: 1.0000
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'Θεαίτητος', 'λέγω', 'θεόδωρος', 'αἰσχρός']
#     Similarity: 0.4141
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'λέγω', 'καλός', 'ἀγαθός']
#     Similarity: 0.7109
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πῶς', 'λέγω']
#     Similarity: 0.4297
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός']
#     Similarity: 0.4453
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω', 'μηδείς', 'δοξάζω', 'αἰσχρός', 'καλός']
#     Similarity: 0.4219
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω', 'μόνος']
#     Similarity: 0.4141
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['οὐκοῦν', 'καλός', 'Σώκρατες', 'λέγω']
#     Similarity: 0.4688
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['καλός', 'λέγω']
#     Similarity: 1.0000
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ἀληθής', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['τρίτος', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['ἐπίσημος', 'πᾶς']
#     Sentence 2: ['πᾶς']
#     Similarity: 0.4609
#   - Sentence 1: ['τρυφά', 'τοιόσδε']
#     Sentence 2: ['τοιόσδε']
#     Similarity: 0.5000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'μέλλω']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'ἀδύνατος']
#     Similarity: 0.5000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['πῶς', 'δέ']
#     Similarity: 0.5156
#   - Sentence 1: ['δέ']
#     Sentence 2: ['οἶδα', 'δέ', 'οἶδα', 'οἶδα']
#     Similarity: 0.4922
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'αὖ']
#     Similarity: 0.5469
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω', 'ὁράω']
#     Similarity: 1.0000
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω']
#     Similarity: 1.0000
#   - Sentence 1: ['οἶδα', 'ἔπος']
#     Sentence 2: ['οἶδα', 'οἶδα']
#     Similarity: 0.4688
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
#   - Sentence 1: ['γιγνώσκω', 'ταῦτ']
#     Sentence 2: ['γιγνώσκω']
#     Similarity: 0.4688
#   - Sentence 1: ['οἶδα', 'τέκνον']
#     Sentence 2: ['οἶδα', 'οἶδα']
#     Similarity: 0.4453
# Theag..with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 1.0000
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 1.0000
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω', 'φημί', 'Σώκρατες', 'ἄπιστος', 'νή', 'θεός', 'ἀληθής']
#     Similarity: 0.4609
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['ὀρθός', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['παρ']
#     Sentence 2: ['παρ', 'ἱππικός']
#     Similarity: 0.4531
#   - Sentence 1: ['πῶς']
#     Sentence 2: ['πῶς']
#     Similarity: 1.0000
#   - Sentence 1: ['δέ']
#     Sentence 2: ['μικρός', 'δέ']
#     Similarity: 0.5469
#   - Sentence 1: ['πάλαι', 'σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 0.5078
#   - Sentence 1: ['πάλαι', 'σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 0.5078
#   - Sentence 1: ['ὀρθός']
#     Sentence 2: ['ὀρθός', 'λέγω']
#     Similarity: 0.4688
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 1.0000
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 1.0000
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 1.0000
#   - Sentence 1: ['σοφός']
#     Sentence 2: ['σοφός']
#     Similarity: 1.0000
#   - Sentence 1: ['φαίνω', 'δῆτ']
#     Sentence 2: ['φαίνω']
#     Similarity: 0.5312
#   - Sentence 1: ['δύναι', 'βούλομαι']
#     Sentence 2: ['βούλομαι']
#     Similarity: 0.4688
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['πάνυ', 'καλός', 'λέγω']
#     Similarity: 0.6484
#   - Sentence 1: ['δέ']
#     Sentence 2: ['μικρός', 'δέ']
#     Similarity: 0.5469
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['πῶς']
#     Similarity: 0.5312
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['ὁράω']
#     Sentence 2: ['ὁράω', 'πάτηρ']
#     Similarity: 0.4609
#   - Sentence 1: ['ποῖος', 'τόπος']
#     Sentence 2: ['ποῖος']
#     Similarity: 0.4922
# Tim..with_lemma.txt
# Sentence pairs with similarity above 0.3 (MinHash):
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['θεός', 'φημί', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5078
#   - Sentence 1: ['μωρός', 'μωρός', 'λέγω']
#     Sentence 2: ['ὅδε', 'λέγω']
#     Similarity: 0.4219
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'ἑξῆς', 'μεταδιωκτέον']
#     Similarity: 0.4062
#   - Sentence 1: ['ὅδε']
#     Sentence 2: ['ὅδε', 'λέγω']
#     Similarity: 0.4453
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.5547
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['εὖ', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['καλός', 'λέγω']
#     Sentence 2: ['ὅδε', 'λέγω']
#     Similarity: 0.4141
#   - Sentence 1: ['δέ']
#     Sentence 2: ['δέ', 'ἑξῆς', 'μεταδιωκτέον']
#     Similarity: 0.4062
#   - Sentence 1: ['πῶς', 'φημί']
#     Sentence 2: ['φημί']
#     Similarity: 0.4688
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['λέγω']
#     Similarity: 0.4922
#   - Sentence 1: ['τοῦτ', 'λέγω']
#     Sentence 2: ['πῶς', 'τοῦτ', 'πῆ', 'εἰκότως', 'διαπορέω', 'λέγω']
#     Similarity: 0.4062
#   - Sentence 1: ['γιγνώσκω', 'ταῦτ']
#     Sentence 2: ['ταῦτ']
#     Similarity: 0.5312

# %% [markdown]
# Über Korpus iterieren und Ausgabe in Dataframe:

# %% [markdown]
# ### Ähnlichkeit basierend auf tfidf:

# %%
#die alte Version war nicht geeignet für große Textmengen, Pandas wird da furchtbar langsam. 
columns = ['text1', 'text2', 'sentence1','sentence2','similarity']
all_rows = []
for f in mycorpus.fileids():
    if f != text1name:
        print(f"Processing {f}...")

        text2 = ' '.join(mycorpus.words(fileids=f))
        tfidf_df, sentences1, sentences2 = calculate_tfidf_similarity(text1, text2)
        pairs = get_sentence_pairs_above_threshold(tfidf_df, sentences1, sentences2, 0.5)

        for pair in pairs:
            all_rows.append([text1name, f, pair['sentence1'], pair['sentence2'], pair['similarity']])
            
df_tfidf = pd.DataFrame(all_rows, columns=columns)
# Out:
# Processing Alc.+1.with_lemma.txt...
# Processing Alc.+2.with_lemma.txt...
# Processing Apol..with_lemma.txt...
# Processing Charm..with_lemma.txt...
# Processing Cleit..with_lemma.txt...
# Processing Crat..with_lemma.txt...
# Processing Criti..with_lemma.txt...
# Processing Crito.with_lemma.txt...
# Processing Epin..with_lemma.txt...
# Processing Epistels.with_lemma.txt...
# Processing Euthyd..with_lemma.txt...
# Processing Euthyph..with_lemma.txt...
# Processing Gorg..with_lemma.txt...
# Processing Hipp.+Maj.with_lemma.txt...
# Processing Hipp.+Min.with_lemma.txt...
# Processing Hipparch..with_lemma.txt...
# Processing Ion.with_lemma.txt...
# Processing Lach..with_lemma.txt...
# Processing Laws.with_lemma.txt...
# Processing Lovers.with_lemma.txt...
# Processing Lysis.with_lemma.txt...
# Processing Menex..with_lemma.txt...
# Processing Meno.with_lemma.txt...
# Processing Minos.with_lemma.txt...
# Processing Parm..with_lemma.txt...
# Processing Phaedo.with_lemma.txt...
# Processing Phaedrus.with_lemma.txt...
# Processing Phileb..with_lemma.txt...
# Processing Prot..with_lemma.txt...
# Processing Republic.with_lemma.txt...
# Processing Soph..with_lemma.txt...
# Processing Stat..with_lemma.txt...
# Processing Sym..with_lemma.txt...
# Processing Theaet..with_lemma.txt...
# Processing Theag..with_lemma.txt...
# Processing Tim..with_lemma.txt...

# %%
df_tfidf
# Out:
#                         text1                  text2  \
# 0      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 1      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 2      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 3      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 4      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# ...                       ...                    ...
# 22684  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 22685  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 22686  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 22687  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 22688  Bakchen.with_lemma.txt    Tim..with_lemma.txt
#
#                                                sentence1  \
# 0                         ἀμφί νάρθηκας ὑβριστής ὁσιοῦσθ
# 1                         ἅμα δέ έὐασμα τοιόσδε ἐπιβρέμω
# 2                    εἶμι εἰσάγγελλε Τειρεσίας ζητέω νιν
# 3                      ἥκω δέ ἑτοῖμος ὅδε ἔχω σκευή θεός
# 4                        ἐξηγέομαι γέρων γέρων τειρεσίης
# ...                                                  ...
# 22684                                      γιγνώσκω ταῦτ
# 22685                                 χαλεπός δέ ὅδε ἥκω
# 22686                                 χαλεπός δέ ὅδε ἥκω
# 22687  ἔρχομαι δέ ὅπου μήτε κιθαιρών ἔμ εἶδον μιαρὸς ...
# 22688                            τοιόσδε ἀποβαίνω πρᾶγμα
#
#                                                sentence2  similarity
# 0                                      ὑβριστής Σώκρατες    0.407940
# 1                                           λέγω τοιόσδε    0.382890
# 2                                                  ζητέω    0.441513
# 3                                                 δέ ἔχω    0.338595
# 4                                          ἔχω ἐξηγέομαι    0.399596
# ...                                                  ...         ...
# 22684                         οὐδαμῶς ταῦτ λέγω Σώκρατες    0.322417
# 22685                                   φάρμακον χαλεπός    0.354181
# 22686                                           ὅδε λέγω    0.350836
# 22687  διό γεγονότος ὁρατός πάντως αἰσθητός μήτηρ ὑπο...    0.369104
# 22688                                    τοιόσδε μάλιστα    0.360720
#
# [22689 rows x 5 columns]

# %% [markdown]
# ### Ähnlichkeit basierend auf fasttext:

# %%
columns = ['text1', 'text2', 'sentence1','sentence2','similarity']
all_rows = []
for f in mycorpus.fileids():
    if f != text1name:
        print(f"Processing {f}...")

        text2 = ' '.join(mycorpus.words(fileids=f))
        fasttext_df, sentences1, sentences2 = calculate_fasttext_similarity(text1, text2)
        pairs = get_sentence_pairs_above_threshold(fasttext_df, sentences1, sentences2, 0.5)

        for pair in pairs:
            all_rows.append([text1name, f, pair['sentence1'], pair['sentence2'], pair['similarity']])
            
df_fasttext = pd.DataFrame(all_rows, columns=columns)
# Out:
# Processing Alc.+1.with_lemma.txt...
# Processing Alc.+2.with_lemma.txt...
# Processing Apol..with_lemma.txt...
# Processing Charm..with_lemma.txt...
# Processing Cleit..with_lemma.txt...
# Processing Crat..with_lemma.txt...
# Processing Criti..with_lemma.txt...
# Processing Crito.with_lemma.txt...
# Processing Epin..with_lemma.txt...
# Processing Epistels.with_lemma.txt...
# Processing Euthyd..with_lemma.txt...
# Processing Euthyph..with_lemma.txt...
# Processing Gorg..with_lemma.txt...
# Processing Hipp.+Maj.with_lemma.txt...
# Processing Hipp.+Min.with_lemma.txt...
# Processing Hipparch..with_lemma.txt...
# Processing Ion.with_lemma.txt...
# Processing Lach..with_lemma.txt...
# Processing Laws.with_lemma.txt...
# Processing Lovers.with_lemma.txt...
# Processing Lysis.with_lemma.txt...
# Processing Menex..with_lemma.txt...
# Processing Meno.with_lemma.txt...
# Processing Minos.with_lemma.txt...
# Processing Parm..with_lemma.txt...
# Processing Phaedo.with_lemma.txt...
# Processing Phaedrus.with_lemma.txt...
# Processing Phileb..with_lemma.txt...
# Processing Prot..with_lemma.txt...
# Processing Republic.with_lemma.txt...
# Processing Soph..with_lemma.txt...
# Processing Stat..with_lemma.txt...
# Processing Sym..with_lemma.txt...
# Processing Theaet..with_lemma.txt...
# Processing Theag..with_lemma.txt...
# Processing Tim..with_lemma.txt...

# %%
df_fasttext
# Out:
#                            text1                  text2  \
# 0         Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 1         Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 2         Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 3         Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 4         Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# ...                          ...                    ...
# 18104900  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 18104901  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 18104902  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 18104903  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 18104904  Bakchen.with_lemma.txt    Tim..with_lemma.txt
#
#                                                   sentence1  \
# 0         [ἥκω, ζεύς, παῖς, θηβαῖος, χθών, Διόνυσος, τίκ...
# 1         [ἥκω, ζεύς, παῖς, θηβαῖος, χθών, Διόνυσος, τίκ...
# 2         [ἥκω, ζεύς, παῖς, θηβαῖος, χθών, Διόνυσος, τίκ...
# 3         [ἥκω, ζεύς, παῖς, θηβαῖος, χθών, Διόνυσος, τίκ...
# 4         [ἥκω, ζεύς, παῖς, θηβαῖος, χθών, Διόνυσος, τίκ...
# ...                                                     ...
# 18104900                        [τοιόσδε, ἀποβαίνω, πρᾶγμα]
# 18104901                        [τοιόσδε, ἀποβαίνω, πρᾶγμα]
# 18104902                        [τοιόσδε, ἀποβαίνω, πρᾶγμα]
# 18104903                        [τοιόσδε, ἀποβαίνω, πρᾶγμα]
# 18104904                        [τοιόσδε, ἀποβαίνω, πρᾶγμα]
#
#                                                   sentence2  similarity
# 0         [παῖς, Κλεινίας, οἶμαι, θαυμάζω, πρῶτος, ἐραστ...    0.606096
# 1         [αἴτιος, γίγνομαι, ἀνθρώπειος, δαιμόνιον, ἐναν...    0.382597
# 2                [νῦν, ἐπεί, οὐκέτι, ἐναντιόω, προσελήλυθα]    0.396342
# 3                        [εὔελπις, δέ, λοιπός, ἐναντιόομαι]    0.457176
# 4         [σχεδόν, κατανενόηκα, χρόνος, σκοπέω, ἐραστής,...    0.300826
# ...                                                     ...         ...
# 18104900  [τέταρτος, γένος, ἔνυδρος, γίγνομαι, μάλιστα, ...    0.451645
# 18104901  [ὅθεν, ἰχθύς, ἔθνος, ὀστρέον, συνάπας, ὅσος, ἔ...    0.449337
# 18104902  [πᾶς, τότε, νῦν, διαμείβω, ζῷον, ἀλλήλων, νόος...    0.555502
# 18104903       [καὶ, τέλος, πᾶς, νῦν, ἤδη, λόγος, φάω, ἔχω]    0.571284
# 18104904  [θνητός, ἀθάνατος, ζῷον, λαμβάνω, συμπληρωθεὶς...    0.504435
#
# [18104905 rows x 5 columns]

# %% [markdown]
# ### Ähnlichkeit basierend auf minhash:

# %%
columns = ['text1', 'text2', 'sentence1','sentence2','similarity']
all_rows = []
for f in mycorpus.fileids():
    if f != text1name:
        print(f"Processing {f}...")

        text2 = ' '.join(mycorpus.words(fileids=f))
        minhash_df, sentences1, sentences2 = calculate_minhash_similarity(text1, text2)
        pairs = get_sentence_pairs_above_threshold(minhash_df, sentences1, sentences2, 0.5)

        for pair in pairs:
            all_rows.append([text1name, f, pair['sentence1'], pair['sentence2'], pair['similarity']])
            
df_minhash = pd.DataFrame(all_rows, columns=columns)
# Out:
# Processing Alc.+1.with_lemma.txt...
# Processing Alc.+2.with_lemma.txt...
# Processing Apol..with_lemma.txt...
# Processing Charm..with_lemma.txt...
# Processing Cleit..with_lemma.txt...
# Processing Crat..with_lemma.txt...
# Processing Criti..with_lemma.txt...
# Processing Crito.with_lemma.txt...
# Processing Epin..with_lemma.txt...
# Processing Epistels.with_lemma.txt...
# Processing Euthyd..with_lemma.txt...
# Processing Euthyph..with_lemma.txt...
# Processing Gorg..with_lemma.txt...
# Processing Hipp.+Maj.with_lemma.txt...
# Processing Hipp.+Min.with_lemma.txt...
# Processing Hipparch..with_lemma.txt...
# Processing Ion.with_lemma.txt...
# Processing Lach..with_lemma.txt...
# Processing Laws.with_lemma.txt...
# Processing Lovers.with_lemma.txt...
# Processing Lysis.with_lemma.txt...
# Processing Menex..with_lemma.txt...
# Processing Meno.with_lemma.txt...
# Processing Minos.with_lemma.txt...
# Processing Parm..with_lemma.txt...
# Processing Phaedo.with_lemma.txt...
# Processing Phaedrus.with_lemma.txt...
# Processing Phileb..with_lemma.txt...
# Processing Prot..with_lemma.txt...
# Processing Republic.with_lemma.txt...
# Processing Soph..with_lemma.txt...
# Processing Stat..with_lemma.txt...
# Processing Sym..with_lemma.txt...
# Processing Theaet..with_lemma.txt...
# Processing Theag..with_lemma.txt...
# Processing Tim..with_lemma.txt...

# %%
df_minhash
# Out:
#                         text1                  text2  \
# 0      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 1      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 2      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 3      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 4      Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# ...                       ...                    ...
# 15144  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 15145  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 15146  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 15147  Bakchen.with_lemma.txt    Tim..with_lemma.txt
# 15148  Bakchen.with_lemma.txt    Tim..with_lemma.txt
#
#                                        sentence1  \
# 0      [ἥκω, δέ, ἑτοῖμος, ὅδε, ἔχω, σκευή, θεός]
# 1                 [ἀλλ, ὁμοίως, θεός, τιμή, ἔχω]
# 2                               [ἀλλ, ἔχω, χείρ]
# 3                               [ἀλλ, ἔχω, χείρ]
# 4                               [ἀλλ, ἔχω, χείρ]
# ...                                          ...
# 15144                               [τοῦτ, λέγω]
# 15145                               [τοῦτ, λέγω]
# 15146                               [τοῦτ, λέγω]
# 15147          [δύστην, ἀλήθει, καιρός, πάρειμι]
# 15148                           [γιγνώσκω, ταῦτ]
#
#                                               sentence2  similarity
# 0                                             [δέ, ἔχω]    0.375000
# 1                                      [ἀλλ, πάνυ, ἔχω]    0.312500
# 2                                      [ἀλλ, πάνυ, ἔχω]    0.507812
# 3                                                 [ἔχω]    0.367188
# 4                              [ἀλλ, εἴπερ, ἔχω, εἶπον]    0.398438
# ...                                                 ...         ...
# 15144                                        [εὖ, λέγω]    0.343750
# 15145          [πῶς, τοῦτ, πῆ, εἰκότως, διαπορέω, λέγω]    0.406250
# 15146                                       [ὅδε, λέγω]    0.351562
# 15147  [τάχ, καιρός, πρέπω, πάρειμι, διακριβολογεῖσθαι]    0.312500
# 15148                                            [ταῦτ]    0.531250
#
# [15149 rows x 5 columns]

# %% [markdown]
# ### Resultat

# %% [markdown]
# Man kann sehen, dass die ähnlichsten Sätze die sind, die nur aus einem Wort bestehen. Es stellt sich die Frage, ob man der Stopwortliste noch andere Worte hätte hinzufügen müssen. Es ist also einen Versuch wert, zu filtern:

# %%
def filter_data_frame(df, n):
    if type(df['sentence1'].iloc[0]) == str:
        df_filtered = df[df['sentence1'].apply(lambda x: len(x.split()) >= n)]
    else:
        df_filtered = df[df['sentence1'].apply(lambda x: len(x) >= n)]
    return df_filtered

# %%
filter_data_frame(df_minhash, 4)
# Out:
#                        text1                   text2  \
# 297   Bakchen.with_lemma.txt  Euthyd..with_lemma.txt
# 298   Bakchen.with_lemma.txt  Euthyd..with_lemma.txt
# 661   Bakchen.with_lemma.txt     Laws.with_lemma.txt
# 1045  Bakchen.with_lemma.txt     Meno.with_lemma.txt
# 1620  Bakchen.with_lemma.txt    Prot..with_lemma.txt
# 1641  Bakchen.with_lemma.txt    Prot..with_lemma.txt
# 1642  Bakchen.with_lemma.txt    Prot..with_lemma.txt
# 2022  Bakchen.with_lemma.txt    Soph..with_lemma.txt
# 2120  Bakchen.with_lemma.txt    Soph..with_lemma.txt
# 1        [οἴει, πρῶτος, κάλλιστός, μέγας, —, πᾶς, δῆλος...    0.531936
# 2        [σύμπας, εἶπον, μέγας, οἴει, δύναμις, ὑπάρχω, ...    0.569192
# 3                                   [προστίθημι, πλουσίων]    0.588525
# 4                 [λέγω, φίλος, παῖς, Κλεινίας, Δεινομάχη]    0.567349
# ...                                                    ...         ...
# 5526779  [κατ, ἐκεῖνος, χρόνος, θεός, συνουσία, ἔρως, ἐ...    0.693636
# 5526780  [τετράπους, γένος, φύω, πολύπους, προφάσεως, θ...    0.646157
# 5526781  [τέταρτος, γένος, ἔνυδρος, γίγνομαι, μάλιστα, ...    0.528396
# 5526782  [ὅθεν, ἰχθύς, ἔθνος, ὀστρέον, συνάπας, ὅσος, ἔ...    0.514328
# 5526783  [θνητός, ἀθάνατος, ζῷον, λαμβάνω, συμπληρωθεὶς...    0.619049
#
# [4650714 rows x 5 columns]

# %%
filter_data_frame(df_tfidf, 4)
# Out:
#                        text1                  text2  \
# 9     Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 19    Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 20    Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 21    Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# 78    Bakchen.with_lemma.txt  Alc.+1.with_lemma.txt
# ...                      ...                    ...
# 4543  Bakchen.with_lemma.txt  Theag..with_lemma.txt
# 4548  Bakchen.with_lemma.txt  Theag..with_lemma.txt
# 4556  Bakchen.with_lemma.txt  Theag..with_lemma.txt
# 4559  Bakchen.with_lemma.txt  Theag..with_lemma.txt
# 4566  Bakchen.with_lemma.txt    Tim..with_lemma.txt
#
#                             sentence1                              sentence2  \
# 9                 διδάσκω σ καλός ἔχω                         ἱκανός διδάσκω
# 19             ὁράω ὁράω δίδωμι ὄργια                                   ὁράω
# 20             ὁράω ὁράω δίδωμι ὄργια                                   ὁράω
# 21    δέ ἱερός νύκτωρ μεθ ἡμέρα τελέω  οἱόμαι νύκτωρ μεθ ἡμέρα ἐξιὼν ἔνδοθεν
# 78               μήν ξυνεθέμην γ θεός                                    μήν
# ...                               ...                                    ...
# 4543           νῦν δέ ὁράω χρή σ ὁράω                             νῦν — ὁράω
# 4548  μόνος πόλις ὅδε ὑπερκάμνω μόνος               ναί ἀλλ λέγω μόνος πόλις
# 4556     ποῖος ἔρχομαι οἶκος ὑμεναῖος                                  ποῖος
# 4559        δῆτα μέλλεθ ἀναγκαῖος ἔχω                                   δῆτα
# 4566     τοῦτ αὖ παρωχέτευσας εὖ λέγω                                εὖ λέγω
#
#       similarity
# 9       0.510363
# 19      0.731223
# 20      0.731223
# 21      0.521312
# 78      0.532532
# ...          ...
# 4543    0.816640
# 4548    0.565922
# 4556    0.510251
# 4559    0.515521
# 4566    0.520903
#
# [341 rows x 5 columns]

# %% [markdown]
# ### Durchschnittliche Ähnlichkeit

# %% [markdown]
# Filtern hilft, um unter den ähnlichen Sätzen die längeren herauszufiltern. Nun wollen wir hingegen schauen, welche Werke Platons den Bakchen - bassierend auf den verschiednen Ähnlichkeitsmaßen - am ähnlichsten sind. Also habe ich die beweiligen Similarity Scores zusammenaddiert, allerdings durch die Länge der verschiedenen Texte dividiert, um die Werte vergleichbar zu machen. Außerdem habe ich die Möglichkeit zu filtern beibelassen: mit n filternt man alle Sätze kürzer n hinaus.

# %%
len_dict = {}
for f in mycorpus.fileids():
    len_dict[f] = len(mycorpus.words(fileids=f))
len_dict
# Out:
# {'Alc.+1.with_lemma.txt': 7418,
#  'Alc.+2.with_lemma.txt': 3002,
#  'Apol..with_lemma.txt': 5859,
#  'Bakchen.with_lemma.txt': 7513,
#  'Charm..with_lemma.txt': 5963,
#  'Cleit..with_lemma.txt': 1065,
#  'Crat..with_lemma.txt': 12400,
#  'Criti..with_lemma.txt': 3436,
#  'Crito.with_lemma.txt': 2776,
#  'Epin..with_lemma.txt': 4482,
#  'Epistels.with_lemma.txt': 11522,
#  'Euthyd..with_lemma.txt': 9416,
#  'Euthyph..with_lemma.txt': 3515,
#  'Gorg..with_lemma.txt': 17921,
#  'Hipp.+Maj.with_lemma.txt': 6038,
#  'Hipp.+Min.with_lemma.txt': 2993,
#  'Hipparch..with_lemma.txt': 1569,
#  'Ion.with_lemma.txt': 2728,
#  'Lach..with_lemma.txt': 5145,
#  'Laws.with_lemma.txt': 71845,
#  'Lovers.with_lemma.txt': 1791,
#  'Lysis.with_lemma.txt': 5120,
#  'Menex..with_lemma.txt': 3246,
#  'Meno.with_lemma.txt': 6737,
#  'Minos.with_lemma.txt': 1941,
#  'Parm..with_lemma.txt': 9988,
#  'Phaedo.with_lemma.txt': 15472,
#  'Phaedrus.with_lemma.txt': 11914,
#  'Phileb..with_lemma.txt': 12873,
#  'Prot..with_lemma.txt': 12337,
#  'Republic.with_lemma.txt': 66360,
#  'Soph..with_lemma.txt': 11401,
#  'Stat..with_lemma.txt': 12091,
#  'Sym..with_lemma.txt': 12385,
#  'Theaet..with_lemma.txt': 15689,
#  'Theag..with_lemma.txt': 2326,
#  'Tim..with_lemma.txt': 16614}

# %%
import matplotlib.pyplot as plt
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### Mit tfidf:

# %%
# Define interactive plotting function
def plot_similarity(n):
    df_filtered = filter_data_frame(df_tfidf, n).groupby('text2', as_index=False)['similarity'].sum()
    for index, row in df_filtered.iterrows():
        df_filtered.loc[index, 'similarity'] = row['similarity']/len_dict[row['text2']]
    
    plt.figure(figsize=(8, 5))
    plt.bar(df_filtered['text2'], df_filtered['similarity'], color='skyblue')
    plt.xlabel('Text Name')
    plt.ylabel('Normalized Similarity')
    plt.title(f'Similarity Sum for n >= {n}')
    plt.xticks(rotation=90)
    plt.show()

# Create slider and display plot interactively
slider = widgets.FloatSlider(min=1, max=10, step=1, value=2, description='n:')
widgets.interactive(plot_similarity, n=slider)
# Out:
# interactive(children=(FloatSlider(value=2.0, description='n:', max=10.0, min=1.0, step=1.0), Output()), _dom_c…

# %% [markdown]
# ### Resultate für TFIDF: Top drei mit n >=:
# ### 1: Sophistes, Alkibiades Major, Parmenides
# ### 2: Alkibiades Major, Sophistes, Lysis
# ### 3: Lysis, Alkibiades Major, Minos
# ### 4: Thegenes, Ion, Minos
# ###
#
#
# ### Resultate für TFIDF mit Similarity Threshold 0.7 statt 0.5:
# ### 1: Sophistes, Parmenides, Lysis
# ### 2: Parmenides, Sophistes, Lysis
# ### 3: Theagenes, Sophistes, Alkibiades Major
# ### 4: Theagenes, Sophistes, Euthydes

# %% [markdown]
# ### Mit Fasttext:

# %%
# Define interactive plotting function
def plot_similarity(n):
    df_filtered = filter_data_frame(df_fasttext, n).groupby('text2', as_index=False)['similarity'].sum()
    for index, row in df_filtered.iterrows():
        df_filtered.loc[index, 'similarity'] = row['similarity']/len_dict[row['text2']]
    
    plt.figure(figsize=(8, 5))
    plt.bar(df_filtered['text2'], df_filtered['similarity'], color='skyblue')
    plt.xlabel('Text Name')
    plt.ylabel('Normalized Similarity')
    plt.title(f'Similarity Sum for n > {n}')
    plt.xticks(rotation=90)
    plt.show()

# Create slider and display plot interactively
slider = widgets.FloatSlider(min=1, max=12, step=1, value=2, description='n:')
widgets.interactive(plot_similarity, n=slider)
# Out:
# interactive(children=(FloatSlider(value=2.0, description='n:', max=12.0, min=1.0, step=1.0), Output()), _dom_c…

# %% [markdown]
# ### Resultate für Fasttext: Top drei mit n >=:
# ### 1, 2, 3 & 4: Minos, Theagenes, Menexenos
# ###
#
# ### Resultate für Fasttext mit Similarity Threshold 0.7 statt 0.5:
# ### 1: Critias, Ion, Minos
# ### 2, 3 & 4: Critias, Ion, Menexenos

# %% [markdown]
# ### Mit minhash:

# %%
# Define interactive plotting function
def plot_similarity(n):
    df_filtered = filter_data_frame(df_minhash, n).groupby('text2', as_index=False)['similarity'].sum()
    for index, row in df_filtered.iterrows():
        df_filtered.loc[index, 'similarity'] = row['similarity']/len_dict[row['text2']]
    
    plt.figure(figsize=(8, 5))
    plt.bar(df_filtered['text2'], df_filtered['similarity'], color='skyblue')
    plt.xlabel('Text Name')
    plt.ylabel('Normalized Similarity')
    plt.title(f'Similarity Sum for n > {n}')
    plt.xticks(rotation=90)
    plt.show()

# Create slider and display plot interactively
slider = widgets.FloatSlider(min=1, max=8, step=1, value=2, description='n:')
widgets.interactive(plot_similarity, n=slider)
# Out:
# interactive(children=(FloatSlider(value=2.0, description='n:', max=8.0, min=1.0, step=1.0), Output()), _dom_cl…

# %% [markdown]
#  ### Resultate für MinHash: Top drei mit n >=:
#  ### 1: Sophistes, Philebus, Parmenides
#  ### 2: Sophistes, Alkibiades Major, Parmenides
#  ### 3: Alkibiades Major, Meno, Sophistes
#  ### 4: ZAHLEN ZU KLEIN
#  ###
#  ### Resultate für MinHash mit Similarity Threshold 0.7 statt 0.5:
#  ### 1: Sophistes, Parmenides, Lysis
#  ### 2: Crito, Philebus, Sophistes
#  ### 3: Menexenus, Lysis, Apologie
#  ### 4: ZAHLEN ZU KLEIN

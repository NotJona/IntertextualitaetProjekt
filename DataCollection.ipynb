# %% [markdown]
# Datensammlung: Sowohl meine Platon Texte als auch die Bakchen des Euripides beziehe ich von der Perseus Digital Library. Besonders was etwaige in ihrer Urheberschaft umstrittene Dialoge angeht, habe ich mich Perseus angeschlossen. Unter dem Gesamtwerk Platons verstehe ich also alle bei Perseus unter "Plato" aufscheinenden Texte.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# Zuerst müssen wir unsere Daten in einem sinnvollen Format sammeln. Damit man die Textstellen nachher auf Perseus finden kann, sammle ich zuerst die verschiedenen Sektionen eines jeden Werkes und greife dann den jeweiligen Text ab, um ihn in einem CSV File zu speichern.

# %%
alkibiades1 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.+1"
alkibiades2 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0175%3Atext%3dAlc.+2"
hipparchus  = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dHipparch."
lovers      = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dLovers"
theages     = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dTheag."
charmides   = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dCharm."
laches      = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dLach."
lysis       = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dLysis"
cratylis    = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0171%3atext%3dCrat."
theaetetus  = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0171%3atext%3dTheaet."
sophist     = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0171%3atext%3dSoph."
statesman   = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0171%3atext%3dStat."
euthydemus  = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0177%3atext%3dEuthyd."
protagoras  = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0177%3atext%3dProt."
gorgias     = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0177%3atext%3dGorg."
meno        = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0177%3atext%3dMeno"
euthyphro   = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0169%3atext%3dEuthyph."
apology     = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0169%3atext%3dApol."
crito       = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0169%3atext%3dCrito"
phaedo      = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0169%3atext%3dPhaedo"
greater_hippias = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dHipp.+Maj."
lesser_hippias  = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dHipp.+Min."
ion         = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dIon"
menexenus   = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dMenex."
cleitophon  = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dCleit."
timaeus     = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dTim."
critias     = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dCriti."
minos       = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dMinos"
epinomis    = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0179%3atext%3dEpin."
parmenides  = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0173%3atext%3dParm."
philebus    = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0173%3atext%3dPhileb."
symposium   = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0173%3atext%3dSym."
phaedrus    = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0173%3atext%3dPhaedrus"

# %%
plato_links = [alkibiades1, alkibiades2, hipparchus, lovers, theages, charmides, laches, lysis, cratylis, theaetetus, sophist, statesman, euthydemus, protagoras, gorgias, meno, euthyphro, apology, crito, phaedo, greater_hippias, lesser_hippias, ion, menexenus, cleitophon, timaeus, critias, minos, epinomis, parmenides, philebus, symposium, phaedrus]
names = ["Alc.+1", "Alc.+2", "Hipparch.", "Lovers", "Theag.", "Charm.", "Lach.", "Lysis", "Crat.", "Theaet.", "Soph.", "Stat.", "Euthyd.", "Prot.", "Gorg.", "Meno", "Euthyph.", "Apol.", "Crito", "Phaedo", "Hipp.+Maj", "Hipp.+Min", "Ion", "Menex.", "Cleit.", "Tim.", "Criti.", "Minos", "Epin.", "Parm.", "Phileb.", "Sym.", "Phaedrus"]

# %%
def get_sections(path):
    response = requests.get(path)
    soup = BeautifulSoup(response.text, 'html.parser')
    noshow_spans = soup.find_all('span', class_='noshow')
    if path == "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0169%3atext%3dEuthyph.":
        section_texts = [span.get_text()[-3:].strip() for span in noshow_spans if span.get_text().startswith("sec")]
    else:
        section_texts = [span.get_text()[-4:].strip() for span in noshow_spans if span.get_text().startswith("sec")]
    return section_texts

# %%
plato_information = []
for i in range(len(plato_links)):
    if names[i] in "Alc.+2":
        link = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0175%3Atext%3DAlc.+2%3Asection%3D138a"
        plato_information.append([names[i], plato_links[i], get_sections(link)])
    elif names[i] == "Hipparch.": 
        link= "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0175%3Atext%3DHipparch.%3Asection%3D225a"
        plato_information.append([names[i], plato_links[i], get_sections(link)])
    else:
        plato_information.append([names[i], plato_links[i], get_sections(plato_links[i])])
print(plato_information)
# Out:
# [['Alc.+1', 'https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.+1', ['103a', '103b', '104a', '104b', '104c', '104d', '104e', '105a', '105b', '105c', '105d', '105e', '106a', '106b', '106c', '106d', '106e', '107a', '107b', '107c', '107d', '107e', '108a', '108b', '108c', '108d', '108e', '109a', '109b', '109c', '109d', '109e', '110a', '110b', '110c', '110d', '110e', '111a', '111b', '111c', '111d', '111e', '112a', '112b', '112c', '112d', '112e', '113a', '113b', '113c', '113d', '113e', '114a', '114b', '114c', '114d', '114e', '115a', '115b', '115c', '115d', '115e', '116a', '116b', '116c', '116d', '116e', '117a', '117b', '117c', '117d', '117e', '118a', '118b', '118c', '118d', '118e', '119a', '119b', '119c', '119d', '119e', '120a', '120b', '120c', '120d', '120e', '121a', '121b', '121c', '121d', '121e', '122a', '122b', '122c', '122d', '122e', '123a', '123b', '123c', '123d', '123e', '124a', '124b', '124c', '124d', '124e', '125a', '125b', '125c', '125d', '1
# ...

# %% [markdown]
# Die drei Werke "Republik", "Gesetze" und "Briefe" sind anders abgespeichert und brauchen ihren eigenen Code

# %%
republic1 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D1%3Asection%3D327a"
republic2 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D2%3Asection%3D357a"
republic3 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D3%3Asection%3D386a"
republic4 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D4%3Asection%3D419a"
republic5 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D5%3Asection%3D449a"
republic6 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D6%3Asection%3D484a"
republic7 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D7%3Asection%3D514a"
republic8 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D8%3Asection%3D543a"
republic9 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D9%3Asection%3D571a"
republic10 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0167%3Abook%3D10%3Asection%3D595a"
rep = [republic1, republic2, republic3, republic4, republic5, republic6,republic7,republic8,republic9,republic10]

for i in range(len(rep)):
    response = requests.get(rep[i])
    soup = BeautifulSoup(response.text, 'html.parser')
    noshow_spans = soup.find_all('span', class_='noshow')
    sections = [span.get_text()[-4:] for span in noshow_spans if span.get_text().startswith("sec")]
    plato_information.append(['rep_book'+str(i+1), rep[i], sections])

# %%
laws1 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D1%3Asection%3D624a"
laws2 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D2%3Asection%3D652a"
laws3 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D3%3Asection%3D676b"
laws4 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D4%3Asection%3D704b"
laws5 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D5%3Asection%3D726a"
laws6 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D6%3Asection%3D751a"
laws7 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D7%3Asection%3D788b"
laws8 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D8%3Asection%3D828b"
laws9 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D9%3Asection%3D853a"
laws10 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D10%3Asection%3D885a"
laws11 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D11%3Asection%3D913a"
laws12 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0165%3Abook%3D12%3Asection%3D941a"
la = [laws1, laws2, laws3, laws4, laws5, laws6, laws7, laws8, laws9, laws10, laws11, laws12]

for i in range(len(la)):
    response = requests.get(la[i])
    soup = BeautifulSoup(response.text, 'html.parser')
    noshow_spans = soup.find_all('span', class_='noshow')
    sections = [span.get_text()[-4:] for span in noshow_spans if span.get_text().startswith("sec")]
    plato_information.append(['law_book'+str(i+1), la[i], sections])

# %%
epistles1 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D1%3Asection%3D309b"
epistles2 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D2%3Asection%3D310b"
epistles3 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D3%3Asection%3D315b"
epistles4 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D4%3Asection%3D320b"
epistles5 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D5%3Asection%3D321c"
epistles6 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D6%3Asection%3D322c"
epistles7 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D7%3Asection%3D324c"
epistles8 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D8%3Asection%3D352b"
epistles9 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D9%3Asection%3D357d"
epistles10 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D10%3Asection%3D358c"
epistles11 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D11%3Asection%3D358d"
epistles12 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D12%3Asection%3D359c"
epistles13 = "https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3Atext%3A1999.01.0163%3Aletter%3D13%3Asection%3D360a"
ep = [epistles1, epistles2, epistles3, epistles4, epistles5, epistles6, epistles7, epistles8, epistles9, epistles10, epistles11, epistles12, epistles13]

for i in range(len(ep)):
    response = requests.get(ep[i])
    soup = BeautifulSoup(response.text, 'html.parser')
    noshow_spans = soup.find_all('span', class_='noshow')
    sections = [span.get_text()[-4:] for span in noshow_spans if span.get_text().startswith("sec")]
    if i == 9:
        sections = ['358c']
    plato_information.append(['letter'+str(i+1), ep[i] ,sections])

# %%
print(plato_information)
# Out:
# [['Alc.+1', 'https://www.perseus.tufts.edu/hopper/text?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.+1', ['103a', '103b', '104a', '104b', '104c', '104d', '104e', '105a', '105b', '105c', '105d', '105e', '106a', '106b', '106c', '106d', '106e', '107a', '107b', '107c', '107d', '107e', '108a', '108b', '108c', '108d', '108e', '109a', '109b', '109c', '109d', '109e', '110a', '110b', '110c', '110d', '110e', '111a', '111b', '111c', '111d', '111e', '112a', '112b', '112c', '112d', '112e', '113a', '113b', '113c', '113d', '113e', '114a', '114b', '114c', '114d', '114e', '115a', '115b', '115c', '115d', '115e', '116a', '116b', '116c', '116d', '116e', '117a', '117b', '117c', '117d', '117e', '118a', '118b', '118c', '118d', '118e', '119a', '119b', '119c', '119d', '119e', '120a', '120b', '120c', '120d', '120e', '121a', '121b', '121c', '121d', '121e', '122a', '122b', '122c', '122d', '122e', '123a', '123b', '123c', '123d', '123e', '124a', '124b', '124c', '124d', '124e', '125a', '125b', '125c', '125d', '1
# ...

# %%
dataframe_plato_information = pd.DataFrame(plato_information, columns=['name', 'link', 'sections'])
dataframe_plato_information
# Out:
#          name                                               link  \
# 0      Alc.+1  https://www.perseus.tufts.edu/hopper/text?doc=...
# 1      Alc.+2  https://www.perseus.tufts.edu/hopper/text?doc=...
# 2   Hipparch.  https://www.perseus.tufts.edu/hopper/text?doc=...
# 3      Lovers  https://www.perseus.tufts.edu/hopper/text?doc=...
# 4      Theag.  https://www.perseus.tufts.edu/hopper/text?doc=...
# ..        ...                                                ...
# 63    letter9  https://www.perseus.tufts.edu/hopper/text?doc=...
# 64   letter10  https://www.perseus.tufts.edu/hopper/text?doc=...
# 65   letter11  https://www.perseus.tufts.edu/hopper/text?doc=...
# 66   letter12  https://www.perseus.tufts.edu/hopper/text?doc=...
# 67   letter13  https://www.perseus.tufts.edu/hopper/text?doc=...
#
#                                              sections
# 0   [103a, 103b, 104a, 104b, 104c, 104d, 104e, 105...
# 1   [138a, 138b, 138c, 138d, 139a, 139b, 139c, 139...
# ...

# %% [markdown]
# Nachdem wir nun für jedes Werk seine Sektionen haben, könnnen wir den jeweiligen Text der Sektion laden und speichern.

# %%
def get_text(link):
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    greek_texts = soup.find_all('p')
    greek_texts = [p.get_text() for p in greek_texts]
    return " ".join(greek_texts)

# %%
def save_as_dataframe(data, name):
    data = pd.DataFrame(data, columns=['section', 'path', 'text'])
    data.to_csv(name+'.csv')

# %%
work = []
for i in range(len(dataframe_plato_information)):
    name_of_work = dataframe_plato_information.iloc[i]['name']
    if name_of_work.startswith("rep"):
        baselink = dataframe_plato_information.iloc[i]['link']
        baselink = baselink.replace('text?', 'xmlchunk?')[:-4]
        for element in dataframe_plato_information.iloc[i]['sections']:
            link = baselink+element
            work.append([name_of_work[8:]+"."+element, link, get_text(link)])
    print(name_of_work)
save_as_dataframe(work, 'Republic')
# Out:
# Alc.+1
# Alc.+2
# Hipparch.
# Lovers
# Theag.
# Charm.
# Lach.
# Lysis
# Crat.
# Theaet.
# Soph.
# Stat.
# Euthyd.
# Prot.
# Gorg.
# Meno
# Euthyph.
# Apol.
# Crito
# Phaedo
# Hipp.+Maj
# Hipp.+Min
# Ion
# Menex.
# Cleit.
# Tim.
# Criti.
# Minos
# Epin.
# Parm.
# Phileb.
# Sym.
# Phaedrus
# C:\Users\Jona\AppData\Local\Programs\Python\Python312\Lib\html\parser.py:171: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
# rep_book1
# rep_book2
# rep_book3
# rep_book4
# rep_book5
# rep_book6
# rep_book7
# rep_book8
# rep_book9
# rep_book10
# law_book1
# law_book2
# law_book3
# law_book4
# ...

# %%
work = []
for i in range(len(dataframe_plato_information)):
    name_of_work = dataframe_plato_information.iloc[i]['name']
    if name_of_work.startswith("law"):
        baselink = dataframe_plato_information.iloc[i]['link']
        baselink = baselink.replace('text?', 'xmlchunk?')[:-4]
        for element in dataframe_plato_information.iloc[i]['sections']:
            link = baselink+element
            work.append([name_of_work[8:]+"."+element, link, get_text(link)])
    print(name_of_work)
save_as_dataframe(work, 'Laws')
# Out:
# Alc.+1
# Alc.+2
# Hipparch.
# Lovers
# Theag.
# Charm.
# Lach.
# Lysis
# Crat.
# Theaet.
# Soph.
# Stat.
# Euthyd.
# Prot.
# Gorg.
# Meno
# Euthyph.
# Apol.
# Crito
# Phaedo
# Hipp.+Maj
# Hipp.+Min
# Ion
# Menex.
# Cleit.
# Tim.
# Criti.
# Minos
# Epin.
# Parm.
# Phileb.
# Sym.
# Phaedrus
# rep_book1
# rep_book2
# rep_book3
# rep_book4
# rep_book5
# rep_book6
# rep_book7
# rep_book8
# rep_book9
# rep_book10
# C:\Users\Jona\AppData\Local\Programs\Python\Python312\Lib\html\parser.py:171: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
# law_book1
# law_book2
# law_book3
# law_book4
# ...

# %%
work = []
for i in range(len(dataframe_plato_information)):
    name_of_work = dataframe_plato_information.iloc[i]['name']
    if name_of_work.startswith("letter"):
        baselink = dataframe_plato_information.iloc[i]['link']
        baselink = baselink.replace('text?', 'xmlchunk?')[:-4]
        for element in dataframe_plato_information.iloc[i]['sections']:
            link = baselink+element
            work.append([name_of_work[6:]+"."+element, link,  get_text(link)])
    print(name_of_work)
save_as_dataframe(work, 'Epistels')
# Out:
# Alc.+1
# Alc.+2
# Hipparch.
# Lovers
# Theag.
# Charm.
# Lach.
# Lysis
# Crat.
# Theaet.
# Soph.
# Stat.
# Euthyd.
# Prot.
# Gorg.
# Meno
# Euthyph.
# Apol.
# Crito
# Phaedo
# Hipp.+Maj
# Hipp.+Min
# Ion
# Menex.
# Cleit.
# Tim.
# Criti.
# Minos
# Epin.
# Parm.
# Phileb.
# Sym.
# Phaedrus
# rep_book1
# rep_book2
# rep_book3
# rep_book4
# rep_book5
# rep_book6
# rep_book7
# rep_book8
# rep_book9
# rep_book10
# law_book1
# law_book2
# law_book3
# law_book4
# law_book5
# law_book6
# law_book7
# law_book8
# law_book9
# law_book10
# law_book11
# law_book12
# ...

# %%
for i in range(33):
    work = []
    name_of_work = dataframe_plato_information.iloc[i]['name']
    baselink = dataframe_plato_information.iloc[i]['link']
    if name_of_work == 'Alc.+1':
        baselink = baselink.replace('.+1', '.%201')
    if name_of_work == 'Alc.+2':
        baselink = baselink.replace('.+2', '.%202')
    if name_of_work == 'Hipp.+Maj':
        baselink = baselink.replace('.+Maj.', '.%20Maj.')
    if name_of_work == 'Hipp.+Min':
        baselink = baselink.replace('.+Min.', '.%20Min.')
    baselink = baselink.replace('text?', 'xmlchunk?')+"%3Asection%3D"
    for element in dataframe_plato_information.iloc[i]['sections']:
        link = baselink+element
        print(link)
        work.append([name_of_work[6:]+"."+element, link, get_text(link)])
    print(name_of_work)
    save_as_dataframe(work, name_of_work)
# Out:
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D103a
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D103b
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D104a
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D104b
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D104c
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D104d
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D104e
# https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3atext%3a1999.01.0175%3atext%3dAlc.%201%3Asection%3D105a
# ...

# %% [markdown]
# Außerdem speichere ich noch jeden Text (alle Sektionen vereint) als txt-File ab.

# %%
import os
for file in os.listdir('CSV Files'):
    print(file)
    df = pd.read_csv(os.path.join('CSV Files', file))
    text = " ".join(df['text'])
    with open(file[:-3]+'txt', 'w', encoding="utf-8") as f:
        f.write(text)
    print('done')
# Out:
# Alc.+1.csv
# done
# Alc.+2.csv
# done
# Apol..csv
# done
# Charm..csv
# done
# Cleit..csv
# done
# Crat..csv
# done
# Criti..csv
# done
# Crito.csv
# done
# Epin..csv
# done
# Epistels.csv
# done
# Euthyd..csv
# done
# Euthyph..csv
# done
# Gorg..csv
# done
# Hipp.+Maj.csv
# done
# Hipp.+Min.csv
# done
# Hipparch..csv
# done
# Ion.csv
# done
# Lach..csv
# done
# Laws.csv
# done
# Lovers.csv
# done
# Lysis.csv
# done
# Menex..csv
# done
# Meno.csv
# done
# Minos.csv
# done
# Parm..csv
# done
# Phaedo.csv
# done
# Phaedrus.csv
# done
# Phileb..csv
# done
# Prot..csv
# done
# Republic.csv
# done
# Soph..csv
# done
# Stat..csv
# done
# Sym..csv
# done
# Theaet..csv
# done
# Theag..csv
# done
# Tim..csv
# done

# %% [markdown]
# Nun das ganze noch für die Bakchen des Euripides:

# %%
sections = [1, 43, 64, 73, 88, 105, 120, 135, 170, 215, 266, 298, 343, 370, 386, 402, 417, 437, 476, 519, 537, 556, 576, 604, 642, 677, 728, 775, 810, 862, 882, 902, 912, 945, 977, 1017, 1024, 1043, 1084, 1114, 1153, 1165, 1168, 1184, 1200, 1244, 1280, 1330, 1368]
work = []
for sec in sections:
    path = "https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3Atext%3A1999.01.0091%3Acard%3D"+str(sec)
    text = get_text(path).replace('\n \n', '\n').replace('\n\n', '\n').replace('--', ' ')
    work.append([str(sec), path, text])
# Out:
# C:\Users\Jona\AppData\Local\Programs\Python\Python312\Lib\html\parser.py:171: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)

# %%
work
# Out:
# [['1',
#   'https://www.perseus.tufts.edu/hopper/xmlchunk?doc=Perseus%3Atext%3A1999.01.0091%3Acard%3D1',
# ...

# %%
save_as_dataframe(work, 'Bakchen')

# %%
text = [sec[2].replace('-\n', '').replace('\n', ' ') for sec in work]
text = " ".join(text)
print(text)
# Out:
#  ἥκω Διὸς παῖς τήνδε Θηβαίων χθόνα Διόνυσος, ὃν τίκτει ποθ᾽ ἡ Κάδμου κόρη Σεμέλη λοχευθεῖσ᾽ ἀστραπηφόρῳ πυρί: μορφὴν δ᾽ ἀμείψας ἐκ θεοῦ βροτησίαν πάρειμι Δίρκης νάματ᾽ Ἰσμηνοῦ θ᾽ ὕδωρ. ὁρῶ δὲ μητρὸς μνῆμα τῆς κεραυνίας τόδ᾽ ἐγγὺς οἴκων καὶ δόμων ἐρείπια τυφόμενα Δίου πυρὸς ἔτι ζῶσαν φλόγα, ἀθάνατον Ἥρας μητέρ᾽ εἰς ἐμὴν ὕβριν. αἰνῶ δὲ Κάδμον, ἄβατον ὃς πέδον τόδε τίθησι, θυγατρὸς σηκόν: ἀμπέλου δέ νιν πέριξ ἐγὼ 'κάλυψα βοτρυώδει χλόῃ. λιπὼν δὲ Λυδῶν τοὺς πολυχρύσους γύας Φρυγῶν τε, Περσῶν θ᾽ ἡλιοβλήτους πλάκας Βάκτριά τε τείχη τήν τε δύσχιμον χθόνα Μήδων ἐπελθὼν Ἀραβίαν τ᾽ εὐδαίμονα Ἀσίαν τε πᾶσαν, ἣ παρ᾽ ἁλμυρὰν ἅλα κεῖται μιγάσιν Ἕλλησι βαρβάροις θ᾽ ὁμοῦ πλήρεις ἔχουσα καλλιπυργώτους πόλεις, ἐς τήνδε πρῶτον ἦλθον Ἑλλήνων πόλιν, τἀκεῖ χορεύσας καὶ καταστήσας ἐμὰς τελετάς, ἵν᾽ εἴην ἐμφανὴς δαίμων βροτοῖς. πρώτας δὲ Θήβας τῆσδε γῆς Ἑλληνίδος ἀνωλόλυξα, νεβρίδ᾽ ἐξάψας χροὸς θύρσον τε δοὺς ἐς χεῖρα, κίσσινον βέλος: ἐπεί μ᾽ ἀδελφαὶ μητρός, ἃς ἥκιστα χρῆν, Διόνυσον οὐκ ἔφασκον ἐκφῦναι Διός
# ...

# %%
with open('Bakchen.txt', 'w', encoding="utf-8") as f:
        f.write(text)

# %%
import os
for file in os.listdir('CSV with Lemmas'):
    print(file)
    df = pd.read_csv(os.path.join('CSV with Lemmas', file))
    text = " ".join(df['lemma_text'])
    with open(file[:-3]+'txt', 'w', encoding="utf-8") as f:
        f.write(text)
    print('done')
